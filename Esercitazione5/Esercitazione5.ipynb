# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import statistics 
from scipy.stats import norm 
from scipy.stats import chi2
from scipy.stats import cauchy

# %% [markdown]
# # Esercitazione 5

# %% [markdown]
# Per il passaggio da coordinate sferiche a cartesiane usa queste conversioni:
#
# $r=\sqrt{x^2+y^2+z^2}$
#
# $r\cos{\theta}=z$
#
# Attenzione che la definizione di $\Psi$ data scambia $\theta$ e $\phi$ rispetto a come li intendi di solito.

# %% [markdown]
# ## Step con distribuzione di probabilità uniforme

# %% [markdown]
# psi100

# %% [markdown]
# Equilibrazione:
#
# $\delta=1.2$

# %%
A=10000  #numero passi
xe=np.arange(A)+1

eu1, au1=np.loadtxt("unif1eq.dat", usecols=(0, 1),  unpack="true")  #valore di r e alpha per ogni step dell'equilibrazione
exu1, eyu1, ezu1=np.loadtxt("unif1eqpos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

eu1fig ,(eu1plt1, eu1plt2, eu1plt3) = plt.subplots(3, 1, figsize=(15, 16), gridspec_kw={'height_ratios': [1, 1, 3]})

eu1plt1.scatter(xe, au1, marker='.', linestyle='', alpha=0.5)
eu1plt1.axhline(y=0.5, color="mediumvioletred", label="Valore target", linewidth=1.5, alpha=0.7)
eu1plt1.axhline(y=np.mean(au1), color="indigo", label="Media dei dati", linewidth=1.5, alpha=0.7)
eu1plt1.set_xlabel("Passi")
eu1plt1.set_ylabel(r"$\alpha$")
eu1plt1.set_title("Analisi dell'accettazione")
eu1plt1.grid(True)
eu1plt1.legend()

eu1plt2.scatter(xe, eu1, marker='.', linestyle='', alpha=0.2)
eu1plt2.axhline(y=3/2, color="mediumvioletred", label="Valore target", linewidth=1.5)
eu1plt2.set_xlabel("Passi")
eu1plt2.set_ylabel(r"$\frac{r}{a_0}$")
eu1plt2.set_title("Analisi del raggio")
eu1plt2.grid(True)
eu1plt2.legend()

eu1plt3.axis('off')
eu1plt3=eu1fig.add_subplot(313, projection='3d')
eu1plt3.scatter(exu1, eyu1, ezu1, marker='.', c=ezu1, alpha=0.3)
eu1plt3.set_xlabel('x')
eu1plt3.set_ylabel('y')
eu1plt3.set_zlabel('z')
eu1plt3.set_title("Sampling ottenuto")
eu1plt3.view_init(10, 30)

eu1fig.suptitle(r"Equilibrazione dell'analisi di $\vert \Psi_{1,0,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità uniforme")

plt.show()

# %% [markdown]
# Analisi:

# %%
M=1000000  #numero step totali
N=100  #numero blocchi
xb=np.arange(N)+1  #ascisse per plot raggio medio

ru1, erroru1=np.loadtxt("unif1rad.dat", usecols=(0, 1),  unpack="true")  #array per plot valor medio di r
xu1, yu1, zu1=np.loadtxt("unif1pos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

u1fig ,(u1plt1, u1plt2) = plt.subplots(1, 2, figsize=(15, 5))

u1plt1.errorbar(xb, ru1, yerr=erroru1)
u1plt1.axhline(y=3/2, color="mediumvioletred", label="Valore atteso", alpha=0.7)
u1plt1.set_xlabel("Blocchi")
u1plt1.set_ylabel(r"$\left\langle \frac{r}{a_0} \right\rangle_{\Psi_{1,0,0}}$")
u1plt1.set_title("Media a blocchi del raggio in unità di raggi di Bohr")
u1plt1.grid(True)

u1plt2.axis('off')
u1plt2=u1fig.add_subplot(122, projection='3d')
u1plt2.scatter(xu1, yu1, zu1, marker='.', c=zu1, alpha=0.3)
u1plt2.set_xlabel('x')
u1plt2.set_ylabel('y')
u1plt2.set_zlabel('z')
u1plt2.set_title(r"Sampling ottenuto")
u1plt2.view_init(10, 30)

u1fig.suptitle(r"Analisi di $\vert \Psi_{1,0,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità uniforme")

plt.show()

# %% [markdown]
# psi210

# %% [markdown]
# Equilibrazione
#
# $\delta=3$

# %%
eu2, au2=np.loadtxt("unif2eq.dat", usecols=(0, 1),  unpack="true")  #valore di r e alpha per ogni step dell'equilibrazione
exu2, eyu2, ezu2=np.loadtxt("unif2eqpos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

eu2fig ,(eu2plt1, eu2plt2, eu2plt3) = plt.subplots(3, 1, figsize=(15, 16), gridspec_kw={'height_ratios': [1, 1, 3]})

eu2plt1.scatter(xe, au2, marker='.', linestyle='', alpha=0.5)
eu2plt1.axhline(y=0.5, color="mediumvioletred", label="Valore target", linewidth=1.5, alpha=0.7)
eu2plt1.axhline(y=np.mean(au2), color="indigo", label="Media dei dati", linewidth=1.5, alpha=0.7)
eu2plt1.set_xlabel("Passi")
eu2plt1.set_ylabel(r"$\alpha$")
eu2plt1.set_title("Analisi dell'accettazione")
eu2plt1.grid(True)
eu2plt1.legend()

eu2plt2.scatter(xe, eu2, marker='.', linestyle='', alpha=0.2)
eu2plt2.axhline(y=5, color="mediumvioletred", label="Valore target", linewidth=1.5)
eu2plt2.set_xlabel("Passi")
eu2plt2.set_ylabel(r"$\frac{r}{a_0}$")
eu2plt2.set_title("Analisi del raggio")
eu2plt2.grid(True)
eu2plt2.legend()

eu2plt3.axis('off')
eu2plt3=eu2fig.add_subplot(313, projection='3d')
eu2plt3.scatter(exu2, eyu2, ezu2, marker='.', c=ezu2, alpha=0.3)
eu2plt3.set_xlabel('x')
eu2plt3.set_ylabel('y')
eu2plt3.set_zlabel('z')
eu2plt3.set_title("Sampling ottenuto")
eu2plt3.view_init(10, 30)

eu2fig.suptitle(r"Equilibrazione dell'analisi di $\vert \Psi_{2,1,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità uniforme")

plt.show()

# %% [markdown]
# Analisi

# %%
ru2, erroru2=np.loadtxt("unif2rad.dat", usecols=(0, 1),  unpack="true")  #array per plot valor medio di r
xu2, yu2, zu2=np.loadtxt("unif2pos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

u2fig ,(u2plt1, u2plt2) = plt.subplots(1, 2, figsize=(15, 5))

u2plt1.errorbar(xb, ru2, yerr=erroru2)
u2plt1.axhline(y=5, color="mediumvioletred", label="Valore atteso", alpha=0.7)
u2plt1.set_xlabel("Blocchi")
u2plt1.set_ylabel(r"$\left\langle \frac{r}{a_0} \right\rangle_{\Psi_{2,1,0}}$")
u2plt1.set_title("Media a blocchi del raggio in unità di raggi di Bohr")
u2plt1.grid(True)

u2plt2.axis('off')
u2plt2=u2fig.add_subplot(122, projection='3d')
u2plt2.scatter(xu2, yu2, zu2, marker='.', c=zu2, alpha=0.3)
u2plt2.set_xlabel('x')
u2plt2.set_ylabel('y')
u2plt2.set_zlabel('z')
u2plt2.set_title(r"Sampling ottenuto")
u2plt2.view_init(10, 30)

u2fig.suptitle(r"Analisi di $\vert \Psi_{2,1,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità uniforme")

plt.show()

# %% [markdown]
# ## Step probabilità gaussiani

# %% [markdown]
# psi100

# %% [markdown]
# Equilibrazione
#
# $\delta=0.7$

# %%
eg1, ag1=np.loadtxt("gaus1eq.dat", usecols=(0, 1),  unpack="true")  #valore di r e alpha per ogni step dell'equilibrazione
exg1, eyg1, ezg1=np.loadtxt("gaus1eqpos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

eg1fig ,(eg1plt1, eg1plt2, eg1plt3) = plt.subplots(3, 1, figsize=(15, 16), gridspec_kw={'height_ratios': [1, 1, 3]})

eg1plt1.scatter(xe, ag1, marker='.', linestyle='', alpha=0.5)
eg1plt1.axhline(y=0.5, color="mediumvioletred", label="Valore target", linewidth=1.5, alpha=0.7)
eg1plt1.axhline(y=np.mean(ag1), color="indigo", label="Media dei dati", linewidth=1.5, alpha=0.7)
eg1plt1.set_xlabel("Passi")
eg1plt1.set_ylabel(r"$\alpha$")
eg1plt1.set_title("Analisi dell'accettazione")
eg1plt1.grid(True)
eg1plt1.legend()

eg1plt2.scatter(xe, eg1, marker='.', linestyle='', alpha=0.2)
eg1plt2.axhline(y=3/2, color="mediumvioletred", label="Valore target", linewidth=1.5)
eg1plt2.set_xlabel("Passi")
eg1plt2.set_ylabel(r"$\frac{r}{a_0}$")
eg1plt2.set_title("Analisi del raggio")
eg1plt2.grid(True)
eg1plt2.legend()

eg1plt3.axis('off')
eg1plt3=eg1fig.add_subplot(313, projection='3d')
eg1plt3.scatter(exg1, eyg1, ezg1, marker='.', c=ezg1, alpha=0.3)
eg1plt3.set_xlabel('x')
eg1plt3.set_ylabel('y')
eg1plt3.set_zlabel('z')
eg1plt3.set_title("Sampling ottenuto")
eg1plt3.view_init(10, 30)

eg1fig.suptitle(r"Equilibrazione dell'analisi di $\vert \Psi_{1,0,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità uniforme")

plt.show()

# %% [markdown]
# Analisi

# %%
rg1, errorg1=np.loadtxt("gaus1rad.dat", usecols=(0, 1),  unpack="true")  #array per plot valor medio di r
xg1, yg1, zg1=np.loadtxt("gaus1pos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

g1fig ,(g1plt1, g1plt2) = plt.subplots(1, 2, figsize=(15, 5))

g1plt1.errorbar(xb, rg1, yerr=errorg1)
g1plt1.axhline(y=3/2, color="mediumvioletred", label="Valore atteso", alpha=0.7)
g1plt1.set_xlabel("Blocchi")
g1plt1.set_ylabel(r"$\left\langle \frac{r}{a_0} \right\rangle_{\Psi_{1,0,0}}$")
g1plt1.set_title("Media a blocchi del raggio in unità di raggi di Bohr")
g1plt1.grid(True)

g1plt2.axis('off')
g1plt2=g1fig.add_subplot(122, projection='3d')
g1plt2.scatter(xg1, yg1, zg1, marker='.', c=zg1, alpha=0.3)
g1plt2.set_xlabel('x')
g1plt2.set_ylabel('y')
g1plt2.set_zlabel('z')
g1plt2.set_title(r"Sampling ottenuto")
g1plt2.view_init(10, 30)

g1fig.suptitle(r"Analisi di $\vert \Psi_{1,0,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità gaussiana")

plt.show()

# %% [markdown]
# psi210

# %% [markdown]
# Equilibrazione
#
# $\delta=2$

# %%
eg2, ag2=np.loadtxt("gaus2eq.dat", usecols=(0, 1),  unpack="true")  #valore di r e alpha per ogni step dell'equilibrazione
exg2, eyg2, ezg2=np.loadtxt("gaus2eqpos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

eg2fig ,(eg2plt1, eg2plt2, eg2plt3) = plt.subplots(3, 1, figsize=(15, 16), gridspec_kw={'height_ratios': [1, 1, 3]})

eg2plt1.scatter(xe, ag2, marker='.', linestyle='', alpha=0.5)
eg2plt1.axhline(y=0.5, color="mediumvioletred", label="Valore target", linewidth=1.5, alpha=0.7)
eg2plt1.axhline(y=np.mean(ag2), color="indigo", label="Media dei dati", linewidth=1.5, alpha=0.7)
eg2plt1.set_xlabel("Passi")
eg2plt1.set_ylabel(r"$\alpha$")
eg2plt1.set_title("Analisi dell'accettazione")
eg2plt1.grid(True)
eg2plt1.legend()

eg2plt2.scatter(xe, eg2, marker='.', linestyle='', alpha=0.2)
eg2plt2.axhline(y=3/2, color="mediumvioletred", label="Valore target", linewidth=1.5)
eg2plt2.set_xlabel("Passi")
eg2plt2.set_ylabel(r"$\frac{r}{a_0}$")
eg2plt2.set_title("Analisi del raggio")
eg2plt2.grid(True)
eg2plt2.legend()

eg2plt3.axis('off')
eg2plt3=eg2fig.add_subplot(313, projection='3d')
eg2plt3.scatter(exg2, eyg2, ezg2, marker='.', c=ezg2, alpha=0.3)
eg2plt3.set_xlabel('x')
eg2plt3.set_ylabel('y')
eg2plt3.set_zlabel('z')
eg2plt3.set_title("Sampling ottenuto")
eg2plt3.view_init(10, 30)

eg2fig.suptitle(r"Equilibrazione dell'analisi di $\vert \Psi_{1,0,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità uniforme")

plt.show()

# %% [markdown]
# Analisi

# %%
rg2, errorg2=np.loadtxt("gaus2rad.dat", usecols=(0, 1),  unpack="true")  #array per plot valor medio di r
xg2, yg2, zg2=np.loadtxt("gaus2pos.dat", usecols=(0, 1, 2),  unpack="true")  #array per plot posizioni in 3d

g2fig ,(g2plt1, g2plt2) = plt.subplots(1, 2, figsize=(15, 5))

g2plt1.errorbar(xb, rg2, yerr=errorg2)
g2plt1.axhline(y=5, color="mediumvioletred", label="Valore atteso", alpha=0.7)
g2plt1.set_xlabel("Blocchi")
g2plt1.set_ylabel(r"$\left\langle \frac{r}{a_0} \right\rangle_{\Psi_{2,1,0}}$")
g2plt1.set_title("Media a blocchi del raggio in unità di raggi di Bohr")
g2plt1.grid(True)

g2plt2.axis('off')
g2plt2=g2fig.add_subplot(122, projection='3d')
g2plt2.scatter(xg2, yg2, zg2, marker='.', c=zg2, alpha=0.3)
g2plt2.set_xlabel('x')
g2plt2.set_ylabel('y')
g2plt2.set_zlabel('z')
g2plt2.set_title(r"Sampling ottenuto")
g2plt2.view_init(10, 30)

g2fig.suptitle(r"Analisi di $\vert \Psi_{2,1,0} \vert ^2$ ottenuta mediante passi con distribuzione di probabilità gaussiana")

plt.show()
